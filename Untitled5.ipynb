# %%
import pandas as pd

# %%
import numpy as np

# %%
import warnings as w

# %%
w.filterwarnings("ignore")

# %%
df= pd.read_csv(r"C:\Users\vkbal\OneDrive\Desktop\datasets.txt")

# %%
df
# Out:
#      name   Age  Gender         D.O.B      Country   Salary
# 0     Tom    25      M    2005-07-06       London     70000
# 1   Jerry    20      M    2003-06-06       London     20000
# 2    Shin    30      F    2004-07-03       Austin     40000
# 3    Chan    15      M    2001-07-06       Europe     60000
# 4    Motu    40      F    2002-01-03      Austria     50000
# 5   Pattu    50      F    2006-08-04      Belgium     70000
# 6   Jeroy    46      M    2003-07-06       Mumbai     30000
# 7    Shan    35      F    2004-08-03    Australia     50000
# 8    Chin    25      M    2001-04-06         Iran     90000
# 9    Monu    50      F    2002-06-03      Vietnam     80000
# 10  Paklu    70      F    2006-01-04      Germany     10000

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', ' D.O.B', 'Country', 'Salary'], dtype='object')

# %%
df.isnull().sum()
# Out:
# name        0
#  Age        0
#  Gender     0
#  D.O.B      0
#  Country    0
#  Salary     0
# dtype: int64

# %%
df[' Gender']
# Out:
# 0      M
# 1      M
# 2      F
# 3      M
# 4      F
# 5      F
# 6      M
# 7      F
# 8      M
# 9      F
# 10     F
# Name:  Gender, dtype: object

# %%
df[' Country'].value_counts()
# Out:
#  Country
# London        2
# Austin        1
# Europe        1
# Austria       1
# Belgium       1
# Mumbai        1
# Australia     1
# Iran          1
# Vietnam       1
# Germany       1
# Name: count, dtype: int64

# %%
df
# Out:
#      name   Age  Gender         D.O.B      Country   Salary
# 0     Tom    25      M    2005-07-06       London     70000
# 1   Jerry    20      M    2003-06-06       London     20000
# 2    Shin    30      F    2004-07-03       Austin     40000
# 3    Chan    15      M    2001-07-06       Europe     60000
# 4    Motu    40      F    2002-01-03      Austria     50000
# 5   Pattu    50      F    2006-08-04      Belgium     70000
# 6   Jeroy    46      M    2003-07-06       Mumbai     30000
# 7    Shan    35      F    2004-08-03    Australia     50000
# 8    Chin    25      M    2001-04-06         Iran     90000
# 9    Monu    50      F    2002-06-03      Vietnam     80000
# 10  Paklu    70      F    2006-01-04      Germany     10000

# %%
df.isnull().sum()
# Out:
# name        0
#  Age        0
#  Gender     0
#  D.O.B      0
#  Country    0
#  Salary     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['name', ' Age', ' Gender', ' D.O.B', ' Country', ' Salary'], dtype='object')

# %%
df.loc[0:6, [' D.O.B', ' Gender']]
# Out:
#           D.O.B Gender
# 0   2005-07-06      M
# 1   2003-06-06      M
# 2   2004-07-03      F
# 3   2001-07-06      M
# 4   2002-01-03      F
# 5   2006-08-04      F
# 6   2003-07-06      M

# %%
df.loc[0:6, [' D.O.B']]
# Out:
#           D.O.B
# 0   2005-07-06
# 1   2003-06-06
# 2   2004-07-03
# 3   2001-07-06
# 4   2002-01-03
# 5   2006-08-04
# 6   2003-07-06

# %%
df.loc[2:6, ['name', ' Gender']]
# Out:
#     name  Gender
# 2   Shin      F
# 3   Chan      M
# 4   Motu      F
# 5  Pattu      F
# 6  Jeroy      M

# %%
df.loc[6:8 , ['name', ' Gender', ' D.O.B', ' Country']]
# Out:
#     name  Gender         D.O.B      Country
# 6  Jeroy      M    2003-07-06       Mumbai
# 7   Shan      F    2004-08-03    Australia
# 8   Chin      M    2001-04-06         Iran

# %%
df.loc[:, ' Gender']
# Out:
# 0      M
# 1      M
# 2      F
# 3      M
# 4      F
# 5      F
# 6      M
# 7      F
# 8      M
# 9      F
# 10     F
# Name:  Gender, dtype: object

# %%
df.iloc[:, :]
# Out:
#      name   Age  Gender         D.O.B      Country   Salary
# 0     Tom    25      M    2005-07-06       London     70000
# 1   Jerry    20      M    2003-06-06       London     20000
# 2    Shin    30      F    2004-07-03       Austin     40000
# 3    Chan    15      M    2001-07-06       Europe     60000
# 4    Motu    40      F    2002-01-03      Austria     50000
# 5   Pattu    50      F    2006-08-04      Belgium     70000
# 6   Jeroy    46      M    2003-07-06       Mumbai     30000
# 7    Shan    35      F    2004-08-03    Australia     50000
# 8    Chin    25      M    2001-04-06         Iran     90000
# 9    Monu    50      F    2002-06-03      Vietnam     80000
# 10  Paklu    70      F    2006-01-04      Germany     10000

# %%
df.iloc[:, 1:2]
# Out:
#     Age
# 0    25
# 1    20
# 2    30
# 3    15
# 4    40
# 5    50
# 6    46
# 7    35
# 8    25
# 9    50
# 10   70

# %%
df.iloc[:, 1]
# Out:
# 0     25
# 1     20
# 2     30
# 3     15
# 4     40
# 5     50
# 6     46
# 7     35
# 8     25
# 9     50
# 10    70
# Name:  Age, dtype: int64

# %%
df.iloc[:, 1:3]
# Out:
#     Age Gender
# 0    25     M
# 1    20     M
# 2    30     F
# 3    15     M
# 4    40     F
# 5    50     F
# 6    46     M
# 7    35     F
# 8    25     M
# 9    50     F
# 10   70     F

# %%
df.iloc[ -1:]
# Out:
#      name   Age  Gender         D.O.B    Country   Salary
# 10  Paklu    70      F    2006-01-04    Germany     10000

# %%
df.iloc[ -2:]
# Out:
#      name   Age  Gender         D.O.B    Country   Salary
# 9    Monu    50      F    2002-06-03    Vietnam     80000
# 10  Paklu    70      F    2006-01-04    Germany     10000

# %%
df.iloc[5:10, 1:]
# Out:
#    Age Gender         D.O.B      Country  Salary
# 5   50     F    2006-08-04      Belgium    70000
# 6   46     M    2003-07-06       Mumbai    30000
# 7   35     F    2004-08-03    Australia    50000
# 8   25     M    2001-04-06         Iran    90000
# 9   50     F    2002-06-03      Vietnam    80000

# %%
df.iloc[2:]
# Out:
#      name   Age  Gender         D.O.B      Country   Salary
# 2    Shin    30      F    2004-07-03       Austin     40000
# 3    Chan    15      M    2001-07-06       Europe     60000
# 4    Motu    40      F    2002-01-03      Austria     50000
# 5   Pattu    50      F    2006-08-04      Belgium     70000
# 6   Jeroy    46      M    2003-07-06       Mumbai     30000
# 7    Shan    35      F    2004-08-03    Australia     50000
# 8    Chin    25      M    2001-04-06         Iran     90000
# 9    Monu    50      F    2002-06-03      Vietnam     80000
# 10  Paklu    70      F    2006-01-04      Germany     10000

# %%
df.iloc[7:]
# Out:
#      name   Age  Gender         D.O.B      Country   Salary
# 7    Shan    35      F    2004-08-03    Australia     50000
# 8    Chin    25      M    2001-04-06         Iran     90000
# 9    Monu    50      F    2002-06-03      Vietnam     80000
# 10  Paklu    70      F    2006-01-04      Germany     10000

# %%
df.iloc[ 4:7, 1:]
# Out:
#    Age Gender         D.O.B    Country  Salary
# 4   40     F    2002-01-03    Austria    50000
# 5   50     F    2006-08-04    Belgium    70000
# 6   46     M    2003-07-06     Mumbai    30000

# %%
df.rename(columns = {'name' : 'Name'}, inplace = True)

# %%
df
# Out:
#      Name   Age  Gender         D.O.B      Country   Salary
# 0     Tom    25      M    2005-07-06       London     70000
# 1   Jerry    20      M    2003-06-06       London     20000
# 2    Shin    30      F    2004-07-03       Austin     40000
# 3    Chan    15      M    2001-07-06       Europe     60000
# 4    Motu    40      F    2002-01-03      Austria     50000
# 5   Pattu    50      F    2006-08-04      Belgium     70000
# 6   Jeroy    46      M    2003-07-06       Mumbai     30000
# 7    Shan    35      F    2004-08-03    Australia     50000
# 8    Chin    25      M    2001-04-06         Iran     90000
# 9    Monu    50      F    2002-06-03      Vietnam     80000
# 10  Paklu    70      F    2006-01-04      Germany     10000

# %%
df.rename(columns = {' Gender': 'Gender'}, inplace = True)

# %%
df
# Out:
#      Name   Age Gender         D.O.B      Country   Salary
# 0     Tom    25     M    2005-07-06       London     70000
# 1   Jerry    20     M    2003-06-06       London     20000
# 2    Shin    30     F    2004-07-03       Austin     40000
# 3    Chan    15     M    2001-07-06       Europe     60000
# 4    Motu    40     F    2002-01-03      Austria     50000
# 5   Pattu    50     F    2006-08-04      Belgium     70000
# 6   Jeroy    46     M    2003-07-06       Mumbai     30000
# 7    Shan    35     F    2004-08-03    Australia     50000
# 8    Chin    25     M    2001-04-06         Iran     90000
# 9    Monu    50     F    2002-06-03      Vietnam     80000
# 10  Paklu    70     F    2006-01-04      Germany     10000

# %%
df.rename(columns = {' Age' : 'Age'}, inplace = True)

# %%
df
# Out:
#      Name  Age Gender         D.O.B      Country   Salary
# 0     Tom   25     M    2005-07-06       London     70000
# 1   Jerry   20     M    2003-06-06       London     20000
# 2    Shin   30     F    2004-07-03       Austin     40000
# 3    Chan   15     M    2001-07-06       Europe     60000
# 4    Motu   40     F    2002-01-03      Austria     50000
# 5   Pattu   50     F    2006-08-04      Belgium     70000
# 6   Jeroy   46     M    2003-07-06       Mumbai     30000
# 7    Shan   35     F    2004-08-03    Australia     50000
# 8    Chin   25     M    2001-04-06         Iran     90000
# 9    Monu   50     F    2002-06-03      Vietnam     80000
# 10  Paklu   70     F    2006-01-04      Germany     10000

# %%
df.rename(columns = {' Country' : 'Country'}, inplace = True)

# %%
df
# Out:
#      Name  Age Gender         D.O.B      Country   Salary
# 0     Tom   25     M    2005-07-06       London     70000
# 1   Jerry   20     M    2003-06-06       London     20000
# 2    Shin   30     F    2004-07-03       Austin     40000
# 3    Chan   15     M    2001-07-06       Europe     60000
# 4    Motu   40     F    2002-01-03      Austria     50000
# 5   Pattu   50     F    2006-08-04      Belgium     70000
# 6   Jeroy   46     M    2003-07-06       Mumbai     30000
# 7    Shan   35     F    2004-08-03    Australia     50000
# 8    Chin   25     M    2001-04-06         Iran     90000
# 9    Monu   50     F    2002-06-03      Vietnam     80000
# 10  Paklu   70     F    2006-01-04      Germany     10000

# %%
df.rename(columns = {' Salary' : 'Salary'}, inplace = True)

# %%
df
# Out:
#      Name  Age Gender         D.O.B      Country  Salary
# 0     Tom   25     M    2005-07-06       London    70000
# 1   Jerry   20     M    2003-06-06       London    20000
# 2    Shin   30     F    2004-07-03       Austin    40000
# 3    Chan   15     M    2001-07-06       Europe    60000
# 4    Motu   40     F    2002-01-03      Austria    50000
# 5   Pattu   50     F    2006-08-04      Belgium    70000
# 6   Jeroy   46     M    2003-07-06       Mumbai    30000
# 7    Shan   35     F    2004-08-03    Australia    50000
# 8    Chin   25     M    2001-04-06         Iran    90000
# 9    Monu   50     F    2002-06-03      Vietnam    80000
# 10  Paklu   70     F    2006-01-04      Germany    10000

# %%
df.shape
# Out:
# (11, 6)

# %%
print("no. of .rows :", df.shape[0])
# Out:
# no. of .rows : 11

# %%
print("no. of. columns :", df.shape[1])
# Out:
# no. of. columns : 6

# %%
df.iloc[0:5]
# Out:
#     Name  Age Gender         D.O.B    Country  Salary
# 0    Tom   25     M    2005-07-06     London    70000
# 1  Jerry   20     M    2003-06-06     London    20000
# 2   Shin   30     F    2004-07-03     Austin    40000
# 3   Chan   15     M    2001-07-06     Europe    60000
# 4   Motu   40     F    2002-01-03    Austria    50000

# %%
df.loc[0:4, ['Name']]
# Out:
#     Name
# 0    Tom
# 1  Jerry
# 2   Shin
# 3   Chan
# 4   Motu

# %%
df.iloc[0:3, 3:]
# Out:
#           D.O.B   Country  Salary
# 0   2005-07-06    London    70000
# 1   2003-06-06    London    20000
# 2   2004-07-03    Austin    40000

# %%
df.iloc[0:3, :3]
# Out:
#     Name  Age Gender
# 0    Tom   25     M
# 1  Jerry   20     M
# 2   Shin   30     F

# %%
df.isnull()
# Out:
#      Name    Age  Gender   D.O.B  Country  Salary
# 0   False  False   False   False    False   False
# 1   False  False   False   False    False   False
# 2   False  False   False   False    False   False
# 3   False  False   False   False    False   False
# 4   False  False   False   False    False   False
# 5   False  False   False   False    False   False
# 6   False  False   False   False    False   False
# 7   False  False   False   False    False   False
# 8   False  False   False   False    False   False
# 9   False  False   False   False    False   False
# 10  False  False   False   False    False   False

# %%
df.isnull().sum()
# Out:
# Name       0
# Age        0
# Gender     0
#  D.O.B     0
# Country    0
# Salary     0
# dtype: int64

# %%
df['Name'][2]= np.nan

# %%
df
# Out:
#      Name  Age Gender         D.O.B      Country  Salary
# 0     Tom   25     M    2005-07-06       London    70000
# 1   Jerry   20     M    2003-06-06       London    20000
# 2     NaN   30     F    2004-07-03       Austin    40000
# 3    Chan   15     M    2001-07-06       Europe    60000
# 4    Motu   40     F    2002-01-03      Austria    50000
# 5   Pattu   50     F    2006-08-04      Belgium    70000
# 6   Jeroy   46     M    2003-07-06       Mumbai    30000
# 7    Shan   35     F    2004-08-03    Australia    50000
# 8    Chin   25     M    2001-04-06         Iran    90000
# 9    Monu   50     F    2002-06-03      Vietnam    80000
# 10  Paklu   70     F    2006-01-04      Germany    10000

# %%
df.isnull()
# Out:
#      Name    Age  Gender   D.O.B  Country  Salary
# 0   False  False   False   False    False   False
# 1   False  False   False   False    False   False
# 2    True  False   False   False    False   False
# 3   False  False   False   False    False   False
# 4   False  False   False   False    False   False
# 5   False  False   False   False    False   False
# 6   False  False   False   False    False   False
# 7   False  False   False   False    False   False
# 8   False  False   False   False    False   False
# 9   False  False   False   False    False   False
# 10  False  False   False   False    False   False

# %%
df.isnull().sum()
# Out:
# Name       1
# Age        0
# Gender     0
#  D.O.B     0
# Country    0
# Salary     0
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F     6
# M     5
# Name: count, dtype: int64

# %%
sum = df['Salary'].sum()

# %%
sum
# Out:
# 570000

# %%
mean = sum / len('Salary')

# %%
mean
# Out:
# 95000.0

# %%
df['Salary']
# Out:
# 0     70000
# 1     20000
# 3     60000
# 4     50000
# 5     70000
# 6     30000
# 7     50000
# 10    10000
# Name: Salary, dtype: int64

# %%
df['Gender'].unique()
# Out:
# array([' M ', ' F '], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df.nunique()
# Out:
# Name       10
# Age         9
# Gender      2
#  D.O.B     11
# Country    10
# Salary      9
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#      Name  Age Gender         D.O.B      Country  Salary
# 0     Tom   25     M    2005-07-06       London    70000
# 1   Jerry   20     M    2003-06-06       London    20000
# 3    Chan   15     M    2001-07-06       Europe    60000
# 4    Motu   40     F    2002-01-03      Austria    50000
# 5   Pattu   50     F    2006-08-04      Belgium    70000
# 6   Jeroy   46     M    2003-07-06       Mumbai    30000
# 7    Shan   35     F    2004-08-03    Australia    50000
# 8    Chin   25     M    2001-04-06         Iran    90000
# 9    Monu   50     F    2002-06-03      Vietnam    80000
# 10  Paklu   70     F    2006-01-04      Germany    10000

# %%
df['Name'].describe()
# Out:
# count      10
# unique     10
# top       Tom
# freq        1
# Name: Name, dtype: object

# %%
df.drop([8,9])
# Out:
#      Name  Age Gender         D.O.B      Country  Salary
# 0     Tom   25     M    2005-07-06       London    70000
# 1   Jerry   20     M    2003-06-06       London    20000
# 3    Chan   15     M    2001-07-06       Europe    60000
# 4    Motu   40     F    2002-01-03      Austria    50000
# 5   Pattu   50     F    2006-08-04      Belgium    70000
# 6   Jeroy   46     M    2003-07-06       Mumbai    30000
# 7    Shan   35     F    2004-08-03    Australia    50000
# 10  Paklu   70     F    2006-01-04      Germany    10000

# %%
df
# Out:
#      Name  Age Gender         D.O.B      Country  Salary
# 0     Tom   25     M    2005-07-06       London    70000
# 1   Jerry   20     M    2003-06-06       London    20000
# 3    Chan   15     M    2001-07-06       Europe    60000
# 4    Motu   40     F    2002-01-03      Austria    50000
# 5   Pattu   50     F    2006-08-04      Belgium    70000
# 6   Jeroy   46     M    2003-07-06       Mumbai    30000
# 7    Shan   35     F    2004-08-03    Australia    50000
# 8    Chin   25     M    2001-04-06         Iran    90000
# 9    Monu   50     F    2002-06-03      Vietnam    80000
# 10  Paklu   70     F    2006-01-04      Germany    10000

# %%
df
# Out:
#      Name  Age Gender         D.O.B      Country  Salary
# 0     Tom   25     M    2005-07-06       London    70000
# 1   Jerry   20     M    2003-06-06       London    20000
# 3    Chan   15     M    2001-07-06       Europe    60000
# 4    Motu   40     F    2002-01-03      Austria    50000
# 5   Pattu   50     F    2006-08-04      Belgium    70000
# 6   Jeroy   46     M    2003-07-06       Mumbai    30000
# 7    Shan   35     F    2004-08-03    Australia    50000
# 8    Chin   25     M    2001-04-06         Iran    90000
# 9    Monu   50     F    2002-06-03      Vietnam    80000
# 10  Paklu   70     F    2006-01-04      Germany    10000

# %%
df.drop([8,9], axis = 0)
# Out:
#      Name  Age Gender         D.O.B      Country  Salary
# 0     Tom   25     M    2005-07-06       London    70000
# 1   Jerry   20     M    2003-06-06       London    20000
# 3    Chan   15     M    2001-07-06       Europe    60000
# 4    Motu   40     F    2002-01-03      Austria    50000
# 5   Pattu   50     F    2006-08-04      Belgium    70000
# 6   Jeroy   46     M    2003-07-06       Mumbai    30000
# 7    Shan   35     F    2004-08-03    Australia    50000
# 10  Paklu   70     F    2006-01-04      Germany    10000

# %%
df
# Out:
#      Name  Age Gender         D.O.B      Country  Salary
# 0     Tom   25     M    2005-07-06       London    70000
# 1   Jerry   20     M    2003-06-06       London    20000
# 3    Chan   15     M    2001-07-06       Europe    60000
# 4    Motu   40     F    2002-01-03      Austria    50000
# 5   Pattu   50     F    2006-08-04      Belgium    70000
# 6   Jeroy   46     M    2003-07-06       Mumbai    30000
# 7    Shan   35     F    2004-08-03    Australia    50000
# 8    Chin   25     M    2001-04-06         Iran    90000
# 9    Monu   50     F    2002-06-03      Vietnam    80000
# 10  Paklu   70     F    2006-01-04      Germany    10000

# %%
df.drop([8,9], axis = 0, inplace = True)

# %%
df
# Out:
#      Name  Age Gender         D.O.B      Country  Salary
# 0     Tom   25     M    2005-07-06       London    70000
# 1   Jerry   20     M    2003-06-06       London    20000
# 3    Chan   15     M    2001-07-06       Europe    60000
# 4    Motu   40     F    2002-01-03      Austria    50000
# 5   Pattu   50     F    2006-08-04      Belgium    70000
# 6   Jeroy   46     M    2003-07-06       Mumbai    30000
# 7    Shan   35     F    2004-08-03    Australia    50000
# 10  Paklu   70     F    2006-01-04      Germany    10000

# %%
df.drop('Age', axis = 1, inplace = True)

# %%
df
# Out:
#      Name Gender         D.O.B      Country  Salary
# 0     Tom     M    2005-07-06       London    70000
# 1   Jerry     M    2003-06-06       London    20000
# 3    Chan     M    2001-07-06       Europe    60000
# 4    Motu     F    2002-01-03      Austria    50000
# 5   Pattu     F    2006-08-04      Belgium    70000
# 6   Jeroy     M    2003-07-06       Mumbai    30000
# 7    Shan     F    2004-08-03    Australia    50000
# 10  Paklu     F    2006-01-04      Germany    10000

# %%
df.drop(['Gender', 'Country'], axis = 1, inplace = True)

# %%
df
# Out:
#      Name         D.O.B  Salary
# 0     Tom   2005-07-06    70000
# 1   Jerry   2003-06-06    20000
# 3    Chan   2001-07-06    60000
# 4    Motu   2002-01-03    50000
# 5   Pattu   2006-08-04    70000
# 6   Jeroy   2003-07-06    30000
# 7    Shan   2004-08-03    50000
# 10  Paklu   2006-01-04    10000

# %%
ds = pd.read_csv

# %%
import pandas as pd 
import numpy as np 
import warnings as w
w.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\vkbal\Downloads\loan_prediction.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 604  LP002959  Female     Yes          1      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 604            12000                0.0       496.0             360.0
# ...

# %%
df.sample()
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 539  LP002740   Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 539             6417                0.0       157.0             180.0
#
#      Credit_History Property_Area Loan_Status
# 539             1.0         Rural           Y

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.rename (columns = {'Loan_ID : LP002978': np.nan })
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 2)

# %%
print(" no of rows :", df.shape[0])
# Out:
#  no of rows : 614

# %%
print("no.of columns :",df.shape[1])
# Out:
# no.of columns : 13

# %%
df = pd.DataFrame(data=df, columns = ['Gender'])

# %%
df
# Out:
#      Gender
# 0      Male
# 1      Male
# 2      Male
# 3      Male
# 4      Male
# ..      ...
# 609  Female
# 610    Male
# 611    Male
# 612    Male
# 613  Female
#
# [614 rows x 1 columns]

# %%
df.iloc[:,1]
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
df = pd.DataFrame(data = df, columns = ['Loan_ID', 'Gender'])

# %%
df
# Out:
#      Loan_ID  Gender
# 0        NaN    Male
# 1        NaN    Male
# 2        NaN    Male
# 3        NaN    Male
# 4        NaN    Male
# ..       ...     ...
# 609      NaN  Female
# 610      NaN    Male
# 611      NaN    Male
# 612      NaN    Male
# 613      NaN  Female
#
# [614 rows x 2 columns]

# %%
ds= df.iloc[:, 1:5]

# %%
ds
# Out:
#      Loan_ID  Gender
# 0        NaN    Male
# 1        NaN    Male
# 2        NaN    Male
# 3        NaN    Male
# 4        NaN    Male
# ..       ...     ...
# 609      NaN  Female
# 610      NaN    Male
# 611      NaN    Male
# 612      NaN    Male
# 613      NaN  Female
#
# [614 rows x 2 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df. loc[:4, ['Loan_ID', 'Gender']]
# Out:
#     Loan_ID Gender
# 0  LP001002   Male
# 1  LP001003   Male
# 2  LP001005   Male
# 3  LP001006   Male
# 4  LP001008   Male

# %%
df[df['Credit_History']== '1.0']
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
df[df['Education'] == 'Not Graduate']
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 6    LP001013   Male     Yes          0  Not Graduate            No
# 16   LP001034   Male      No          1  Not Graduate            No
# 18   LP001038   Male     Yes          0  Not Graduate            No
# 20   LP001043   Male     Yes          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 595  LP002940   Male      No          0  Not Graduate            No
# 596  LP002941   Male     Yes          2  Not Graduate           Yes
# 601  LP002950   Male     Yes          0  Not Graduate           NaN
# 605  LP002960   Male     Yes          0  Not Graduate            No
# 607  LP002964   Male     Yes          2  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 3               2583             2358.0       120.0             360.0
# ...

# %%
df[(df['Education']== 'Not Graduate')  & (df['LoanAmount'] >100.0)]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 18   LP001038   Male     Yes          0  Not Graduate            No
# 20   LP001043   Male     Yes          0  Not Graduate            No
# 22   LP001047   Male     Yes          0  Not Graduate            No
# 23   LP001050    NaN     Yes          2  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 573  LP002862   Male     Yes          2  Not Graduate            No
# 595  LP002940   Male      No          0  Not Graduate            No
# 596  LP002941   Male     Yes          2  Not Graduate           Yes
# 601  LP002950   Male     Yes          0  Not Graduate           NaN
# 607  LP002964   Male     Yes          2  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 3               2583             2358.0       120.0             360.0
# ...

# %%
df[df['Loan_ID'].isna()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
df[df['Loan_ID'].isna()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df[(df['Gender']=='M') | (df['Property_Area']== 'Rural')]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 18   LP001038    Male     Yes          0  Not Graduate            No
# 23   LP001050     NaN     Yes          2  Not Graduate            No
# 32   LP001097    Male      No          1      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 603  LP002958    Male      No          0      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df[df['Property_Area'].isna()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
df.drop('Dependents', axis = 1, inplace =True)

# %%
df
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0    LP001002    Male      No      Graduate            No             5849
# 1    LP001003    Male     Yes      Graduate            No             4583
# 2    LP001005    Male     Yes      Graduate           Yes             3000
# 3    LP001006    Male     Yes  Not Graduate            No             2583
# 4    LP001008    Male      No      Graduate            No             6000
# ..        ...     ...     ...           ...           ...              ...
# 609  LP002978  Female      No      Graduate            No             2900
# 610  LP002979    Male     Yes      Graduate            No             4106
# 611  LP002983    Male     Yes      Graduate            No             8072
# 612  LP002984    Male     Yes      Graduate            No             7583
# 613  LP002990  Female      No      Graduate           Yes             4583
#
# ...

# %%
dict1 = { 's.no' : [1,2,3], 'name' : ['tom', 'jerry', 'shin'], 'salary' : [20000,15000,10000]}

# %%
df2= pd.DataFrame(dict1)

# %%
df2
# Out:
#    s.no   name  salary
# 0     1    tom   20000
# 1     2  jerry   15000
# 2     3   shin   10000

# %%
dict3 = { 's.no' : [4, 5, 6], 'name' : ['tomi', 'jerrio', 'shiku'], 'salary' : [40000,30000,15000]}

# %%
df5 = pd.DataFrame(dict3)

# %%
df5
# Out:
#    s.no    name  salary
# 0     4    tomi   40000
# 1     5  jerrio   30000
# 2     6   shiku   15000

# %%
df_merge = pd.concat([df2, df5])

# %%
df_merge
# Out:
#    s.no    name  salary
# 0     1     tom   20000
# 1     2   jerry   15000
# 2     3    shin   10000
# 0     4    tomi   40000
# 1     5  jerrio   30000
# 2     6   shiku   15000

# %%
df_merge = pd.concat([df2, df5], ignore_index = True)

# %%
df_merge
# Out:
#    s.no    name  salary
# 0     1     tom   20000
# 1     2   jerry   15000
# 2     3    shin   10000
# 3     4    tomi   40000
# 4     5  jerrio   30000
# 5     6   shiku   15000

# %%
df.drop([2,3], axis = 0 , inplace = True)

# %%
df
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0    LP001002    Male      No      Graduate            No             5849
# 1    LP001003    Male     Yes      Graduate            No             4583
# 4    LP001008    Male      No      Graduate            No             6000
# 5    LP001011    Male     Yes      Graduate           Yes             5417
# 6    LP001013    Male     Yes  Not Graduate            No             2333
# ..        ...     ...     ...           ...           ...              ...
# 609  LP002978  Female      No      Graduate            No             2900
# 610  LP002979    Male     Yes      Graduate            No             4106
# 611  LP002983    Male     Yes      Graduate            No             8072
# 612  LP002984    Male     Yes      Graduate            No             7583
# 613  LP002990  Female      No      Graduate           Yes             4583
#
# ...

# %%
df.drop(['Loan_ID'], axis = 1 , inplace = True)

# %%
df
# Out:
#      Gender Married     Education Self_Employed  ApplicantIncome  \
# 0      Male      No      Graduate            No             5849
# 1      Male     Yes      Graduate            No             4583
# 4      Male      No      Graduate            No             6000
# 5      Male     Yes      Graduate           Yes             5417
# 6      Male     Yes  Not Graduate            No             2333
# ..      ...     ...           ...           ...              ...
# 609  Female      No      Graduate            No             2900
# 610    Male     Yes      Graduate            No             4106
# 611    Male     Yes      Graduate            No             8072
# 612    Male     Yes      Graduate            No             7583
# 613  Female      No      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# ...

# %%
df['Education'].value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
for i in df.columns :
    df.head()
print(df.head(4))
print("________________________________________________________________________________________________________")
print("\n")
print(df['Education'].value_counts())
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# ...

# %%
    df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
for i in df.columns :
    if df[i].dtype == 'object'  :
        print(df[i].value_counts())
# Out:
# Loan_ID
# LP001002    1
# LP002328    1
# LP002305    1
# LP002308    1
# LP002314    1
#            ..
# LP001692    1
# LP001693    1
# LP001698    1
# LP001699    1
# LP002990    1
# Name: count, Length: 614, dtype: int64
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64
# Married
# Yes    398
# No     213
# Name: count, dtype: int64
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64
